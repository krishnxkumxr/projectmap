# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from bs4 import BeautifulSoup
#       5 import requests
#       6 import seaborn as sns
#
# ModuleNotFoundError: No module named 'bs4'

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
list_ = {}
for i,j in zip(df['label'].unique(),range(len(list(df['label'].unique())))):
    list_[i] = j

df['Label_Num'] = df['label'].apply(lambda x: list_[x])

# %%
df.drop(['label'],axis=1,inplace=True)

# %%
# X = df[[col for col in df.columns if col != "Label_Num"]]
X = df[['temperature','humidity','ph','rainfall']]
Y = df['Label_Num']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.30)

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,mean_absolute_error

models = {
    "Linear Classification" : LogisticRegression(),
    "SVC" : SVC(),
    "K Nearest" : KNeighborsClassifier(),
    "Decision Tree" : DecisionTreeClassifier(),
    "Ada Boost" : AdaBoostClassifier(),
    "Gradient" : GradientBoostingClassifier(),
    "XGB" : XGBClassifier()
}

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train,Y_train)
    Y_pred = model.predict(X_test)

    acc = accuracy_score(Y_test,Y_pred)
    mae = mean_absolute_error(Y_test,Y_pred)
    print(f"R2 value for {list(models.keys())[i]} : ", acc*100)
    print(f"MAE value for {list(models.keys())[i]} : ", mae)
    print("-"*50) # Just to make a boundary
# Out:
# R2 value for Linear Classification :  79.6969696969697
# MAE value for Linear Classification :  1.3681818181818182
# --------------------------------------------------
# R2 value for SVC :  89.39393939393939
# MAE value for SVC :  0.7742424242424243
# --------------------------------------------------
# R2 value for K Nearest :  89.39393939393939
# MAE value for K Nearest :  0.806060606060606
# --------------------------------------------------
# R2 value for Decision Tree :  93.48484848484848
# MAE value for Decision Tree :  0.4954545454545455
# --------------------------------------------------
# C:\Users\kunsh\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# R2 value for Ada Boost :  12.575757575757576
# MAE value for Ada Boost :  4.634848484848485
# --------------------------------------------------
# R2 value for Gradient :  94.0909090909091
# MAE value for Gradient :  0.41363636363636364
# --------------------------------------------------
# R2 value for XGB :  95.3030303030303
# MAE value for XGB :  0.2787878787878788
# --------------------------------------------------

# %%
model = GradientBoostingClassifier()
model.fit(X_train,Y_train)
# Out:
# GradientBoostingClassifier()

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model, X, Y, cv=5, scoring='r2')  # 5-fold cross-validation

print("R² scores from each fold:", scores)
print("Average R² score:", round(np.mean(scores)*100, 2), "%")
# Out:
# R² scores from each fold: [0.95070582 0.84297007 0.89062676 0.85183512 0.8338227 ]
# Average R² score: 87.4 %

# %%
    Prediction = model.predict(scale.transform([[31.15 , 74.12,7.7, 677.66 ]]))
for crop,num in list_.items():
    if num == Prediction:
        print(f"Predicted Crop is : {crop.upper()}")
        break
# Out:
# Predicted Crop is : RICE
# C:\Users\kunsh\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
df[['temperature','humidity','ph','rainfall']]
# Out:
#       temperature   humidity        ph    rainfall
# 0       20.879744  82.002744  6.502985  202.935536
# 1       21.770462  80.319644  7.038096  226.655537
# 2       23.004459  82.320763  7.840207  263.964248
# 3       26.491096  80.158363  6.980401  242.864034
# 4       20.130175  81.604873  7.628473  262.717340
# ...           ...        ...       ...         ...
# 2195    26.774637  66.413269  6.780064  177.774507
# 2196    27.417112  56.636362  6.086922  127.924610
# 2197    24.131797  67.225123  6.362608  173.322839
# 2198    26.272418  52.127394  6.758793  127.175293
# 2199    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 4 columns]

# %%
df.to_excel("Crop_Label_Num.xlsx")
